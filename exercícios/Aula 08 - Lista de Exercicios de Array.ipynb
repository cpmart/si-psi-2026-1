// %% [markdown]
// # Exercícios — Objeto Array em JavaScript

// %% [markdown]
// ## Exercício — Agenda de Contatos
//
// **Métodos:** `push()`, `pop()`, `shift()`, `unshift()`, `length`
//
// Crie e manipule um array de nomes usando os métodos fundamentais de inserção e remoção.
//
// **O que implementar:**
// 1. Inicie com um array vazio de contatos
// 2. Adicione 5 nomes ao **final** com `push()`
// 3. Remova o último contato com `pop()` e exiba o nome removido
// 4. Adicione um contato urgente no **início** com `unshift()`
// 5. Remova o primeiro contato com `shift()` e exiba-o
// 6. Exiba o total de contatos restantes com `length`
//
// > 💡 **Dica:** Pense em `push`/`pop` como uma pilha de pratos e `shift`/`unshift` como uma fila no caixa.

// %%
// Exercício — Agenda de Contatos
// Escreva sua solução abaixo

let contatos = [];

// 1. Adicione 5 nomes ao final com push()


// 2. Remova o último com pop() e exiba o nome removido


// 3. Adicione um contato urgente no início com unshift()


// 4. Remova o primeiro com shift() e exiba-o


// 5. Exiba o total de contatos restantes
console.log('Contatos restantes:', contatos.length);
console.log('Lista final:', contatos);

// %% [markdown]
// ## Exercício — Extrator de Dados de String
//
// **Métodos:** `split()`, `join()`, `reverse()`
//
// Use `split()` para dividir strings em arrays e `join()` para recompô-las de formas diferentes.
//
// **O que implementar:**
// 1. Divida a string `'JavaScript é uma linguagem incrível'` em palavras
// 2. Una o array de palavras com traço `-` como separador
// 3. Inverta a ordem das palavras e rejunte em frase
// 4. Divida uma data no formato `'25/04/2025'` e exiba dia, mês e ano separadamente
// 5. Reconstrua a data no formato `'2025-04-25'`
//
// > 💡 **Dica:** `split()` é método de `String`, não de `Array` — mas retorna um `Array`.

// %%
// Exercício — Extrator de Dados de String

const frase = 'JavaScript é uma linguagem incrível';
const data = '25/04/2025';

// 1. Divida a frase em palavras


// 2. Una com traço


// 3. Inverta e rejunte


// 4. Divida a data e exiba partes


// 5. Reconstrua no formato aaaa-mm-dd

// %% [markdown]
// ## Exercício — Buscador de Produtos
//
// **Métodos:** `indexOf()`, `includes()`, `find()`, `findIndex()`
//
// Pratique os métodos de busca para localizar elementos em um array de produtos.
//
// **O que implementar:**
// 1. Crie um array com 6 nomes de produtos
// 2. Verifique se `'Teclado'` está no array com `includes()`
// 3. Descubra a posição de `'Mouse'` com `indexOf()`
// 4. Crie um array de objetos `{ nome, preco }` e use `find()` para retornar o primeiro produto com preço acima de R$ 100
// 5. Use `findIndex()` para obter a posição desse produto
// 6. Tente buscar um produto inexistente e trate o resultado `undefined`
//
// > 💡 **Dica:** Atenção: `indexOf()` não encontra `NaN` corretamente — para esse caso use `includes()`.

// %%
// Exercício 03 — Buscador de Produtos

// 1. Array de nomes de produtos
const nomeProdutos = ['Monitor', 'Teclado', 'Mouse', 'Headset', 'Webcam', 'Hub USB'];

// 2. Verifique com includes()


// 3. Posição do Mouse com indexOf()


// 4. Array de objetos e find()
const produtos = [
  { nome: 'Monitor', preco: 850 },
  { nome: 'Teclado', preco: 95 },
  { nome: 'Mouse', preco: 120 },
  { nome: 'Headset', preco: 75 },
  { nome: 'Webcam', preco: 230 },
];

// 5. findIndex()


// 6. Produto inexistente — trate undefined

// %% [markdown]
// ## Exercício — Fatiador de Turmas
//
// **Métodos:** `slice()`, `splice()`, `concat()`
//
// Pratique extração e modificação de partes de um array de alunos.
//
// **O que implementar:**
// 1. Crie um array com 10 nomes de alunos
// 2. Extraia os 3 primeiros alunos com `slice()` **sem alterar o original**
// 3. Extraia os últimos 2 alunos usando índices negativos
// 4. Use `splice()` para remover o 5º aluno e exiba quem foi removido
// 5. Use `splice()` para inserir um novo aluno na 3ª posição
// 6. Combine dois grupos de alunos com `concat()`
//
// > 💡 **Dica:** `slice()` não altera o original; `splice()` sim — cuidado ao usar sem querer mutabilidade.

// %%
// Exercício — Fatiador de Turmas

let alunos = ['Ana', 'Bruno', 'Carla', 'Diego', 'Elisa', 'Felipe', 'Gabi', 'Hugo', 'Ísis', 'João'];

// 2. Extraia os 3 primeiros com slice()


// 3. Extraia os últimos 2 com índice negativo


// 4. Remova o 5º aluno com splice() e exiba quem foi removido


// 5. Insira 'Kamila' na 3ª posição com splice()


// 6. Combine dois grupos com concat()
const grupoB = ['Lucas', 'Mariana', 'Nicolas'];

// %% [markdown]
// ## Exercício — Verificador de Turma
//
// **Métodos:** `every()`, `some()`, `filter()`
//
// Use `every()` e `some()` para validar condições em um array de notas.
//
// **O que implementar:**
// 1. Use o array de notas fornecido: `[7.5, 8.0, 5.5, 9.0, 6.0, 4.5, 7.0]`
// 2. Verifique com `every()` se todos os alunos tiraram nota acima de 4
// 3. Verifique com `some()` se algum aluno tirou 10
// 4. Verifique com `some()` se há algum aluno reprovado (nota < 5)
// 5. Exiba mensagens descritivas para cada verificação
// 6. Use `every()` para checar se todas as notas são do tipo `number`
//
// > 💡 **Dica:** `every()` para 'todos'; `some()` para 'pelo menos um' — equivalem ao `all()`/`any()` do Python.

// %%
// Exercício — Verificador de Turma

const notas = [7.5, 8.0, 5.5, 9.0, 6.0, 4.5, 7.0];

// 2. Todos acima de 4?


// 3. Algum tirou 10?


// 4. Algum reprovado (nota < 5)?


// 5. Exiba mensagens descritivas para cada verificação


// 6. Todas as notas são do tipo number?

// %% [markdown]
// ## Encadeamento e composição de métodos
//
// Todos os exercícios exigem encadeamento de 3 ou mais métodos, onde a saída de um alimenta o próximo. Explore o estilo funcional: `array.filter(...).map(...).reduce(...)`.

// %% [markdown]
// ## Exercício — Relatório de Vendas
//
// **Métodos:** `filter()` → `map()` → `reduce()` → `sort()` → `slice()`
//
// Encadeie métodos para extrair e sumarizar dados de vendas.
//
// **O que implementar:**
// 1. Use o array de vendas fornecido com objetos `{ produto, valor, categoria, vendedor }`
// 2. Filtre apenas as vendas da categoria `'Eletrônicos'`
// 3. Sobre o resultado, use `map()` para extrair apenas os valores
// 4. Use `reduce()` para calcular o total vendido nessa categoria
// 5. Em outra cadeia: ordene **todas** as vendas por valor (decrescente) e extraia o top-3 com `slice()`
// 6. Exiba nome e valor formatado dos top-3 com outro `map()`
//
// > 💡 **Dica:** Encadeie: `array.filter(...).map(...).reduce(...)` — cada método recebe o resultado do anterior.

// %%
// Exercício — Relatório de Vendas

const vendas = [
  { produto: 'Notebook',    valor: 3500, categoria: 'Eletrônicos',  vendedor: 'Ana' },
  { produto: 'Cadeira',     valor: 890,  categoria: 'Móveis',        vendedor: 'Bruno' },
  { produto: 'Smartphone',  valor: 2100, categoria: 'Eletrônicos',  vendedor: 'Carla' },
  { produto: 'Mesa',        valor: 1200, categoria: 'Móveis',        vendedor: 'Ana' },
  { produto: 'Tablet',      valor: 1500, categoria: 'Eletrônicos',  vendedor: 'Diego' },
  { produto: 'Sofá',        valor: 2800, categoria: 'Móveis',        vendedor: 'Carla' },
  { produto: 'Monitor',     valor: 950,  categoria: 'Eletrônicos',  vendedor: 'Bruno' },
  { produto: 'Impressora',  valor: 680,  categoria: 'Eletrônicos',  vendedor: 'Ana' },
];

// 2-4. Total de vendas da categoria Eletrônicos (filter → map → reduce)


// 5-6. Top-3 vendas (sort → slice → map para exibição)

// %% [markdown]
// ## Exercício — Limpador de Dados Duplicados
//
// **Métodos:** `map()` → `Set` + `spread` → `filter()` → `sort()`
//
// Combine `Set` com o operador spread e métodos de array para eliminar duplicatas e normalizar dados.
//
// **O que implementar:**
// 1. Use o array de e-mails com repetidos e caixas mistas fornecido
// 2. Use `map()` para converter todos para minúsculas
// 3. Aplique spread + Set para remover duplicatas: `[...new Set(array)]`
// 4. Filtre apenas e-mails válidos (que contenham `'@'`)
// 5. Ordene o resultado alfabeticamente com `sort()`
// 6. Exiba a contagem antes e depois com `length`
//
// > 💡 **Dica:** `Set` compara por valor para primitivos como strings — duplicatas idênticas (após lowercase) são eliminadas automaticamente.

// %%
// Exercício — Limpador de Dados Duplicados

const emailsBrutos = [
  'Ana@email.com', 'ana@email.com', 'BRUNO@email.com',
  'carla@email.com', 'diego@email', // e-mail inválido
  'Bruno@email.com', 'elisa@email.com', 'ANA@EMAIL.COM',
  'felipe@email.com', 'carla@email.com', 'invalido-sem-arroba',
];

console.log('Total bruto:', emailsBrutos.length);

// 2. Lowercase com map()


// 3. Remover duplicatas com Set + spread


// 4. Filtrar apenas válidos (contém '@')


// 5. Ordenar alfabeticamente


// 6. Exibir resultado final
console.log('Total limpo:', /* sua variável */.length);

// %% [markdown]
// ## Exercício — Agrupador de Alunos por Turma
//
// **Métodos:** `reduce()`, `filter()`, `map()`, `find()`, `sort()`
//
// Use `reduce()` para transformar um array plano em estrutura agrupada, depois extraia subconjuntos e estatísticas.
//
// **O que implementar:**
// 1. Use o array de alunos `{ nome, turma, nota }` fornecido
// 2. Use `reduce()` para agrupar em `{ 'Turma A': [...], 'Turma B': [...] }`
// 3. Para cada turma, calcule a média de notas com `reduce()`
// 4. Identifique com `find()` ou `sort()` o aluno com maior nota em cada turma
// 5. Gere um array de objetos resumo: `[{ turma, media, destaque }]`
// 6. Ordene o resumo pela média (decrescente)
//
// > 💡 **Dica:** No `reduce` de agrupamento: `acc[turma] = acc[turma] || []` e depois faça `push` do aluno.

// %%
// Exercício — Agrupador de Alunos por Turma

const alunos = [
  { nome: 'Ana',     turma: 'Turma A', nota: 8.5 },
  { nome: 'Bruno',   turma: 'Turma B', nota: 7.0 },
  { nome: 'Carla',   turma: 'Turma A', nota: 9.2 },
  { nome: 'Diego',   turma: 'Turma C', nota: 6.5 },
  { nome: 'Elisa',   turma: 'Turma B', nota: 8.8 },
  { nome: 'Felipe',  turma: 'Turma C', nota: 7.4 },
  { nome: 'Gabi',    turma: 'Turma A', nota: 7.9 },
  { nome: 'Hugo',    turma: 'Turma B', nota: 6.2 },
  { nome: 'Ísis',    turma: 'Turma C', nota: 9.0 },
  { nome: 'João',    turma: 'Turma A', nota: 8.1 },
];

// 2. Agrupar por turma com reduce()


// 3. Calcular média de cada turma


// 4. Aluno destaque (maior nota) de cada turma


// 5-6. Resumo ordenado por média

// %% [markdown]
// ## Exercício — Sistema de Gerenciamento de Tarefas (To-Do Avançado)
//
// **Métodos:** `splice()`, `filter()`, `map()`, `sort()`, `find()`, `reduce()`, `Set`, spread
//
// Implemente um CRUD completo de tarefas com prioridades, tags, filtros combinados e histórico de ações.
//
// **Estrutura de dados:**
// ```javascript
// { id, titulo, descricao, prioridade (1-3), tags: [], concluida, criadaEm, concluidaEm }
// ```
//
// **O que implementar:**
// 1. Funções CRUD: `criarTarefa()`, `editarTarefa()` (com spread para imutabilidade), `concluirTarefa()`, `removerTarefa()`
// 2. Filtros combinados: por tag (usando `some()`), por prioridade, por status, por intervalo de datas
// 3. Ordenação multi-critério: prioridade desc + data de criação asc (função comparadora complexa no `sort()`)
// 4. Estatísticas com `reduce()`: total por prioridade, tempo médio de conclusão, tags mais usadas
// 5. Histórico de ações: array de `{ acao, tarefaId, timestamp }` — implemente `desfazer()` restaurando o estado anterior
// 6. Busca textual: `filter()` com `includes()` no título e descrição (case-insensitive)
// 7. Teste o sistema com pelo menos 6 tarefas, realizando criação, edição, conclusão e remoção
//
// > 💡 **Dica:** Use `[...tarefas]` antes de `sort()` para não mutar o array original — mantenha imutabilidade no estado.

// %%
// Exercício — Sistema de Gerenciamento de Tarefas

let tarefas = [];
let historico = [];
let _idCounter = 1;

// --- CRUD ---

function criarTarefa(titulo, descricao, prioridade = 2, tags = []) {
  // Implemente: adicione a tarefa ao array e registre no histórico
}

function editarTarefa(id, alteracoes) {
  // Implemente: use spread para criar nova versão sem mutar o original
  // Dica: tarefas = tarefas.map(t => t.id === id ? { ...t, ...alteracoes } : t)
}

function concluirTarefa(id) {
  // Implemente: marque concluida = true e registre concluidaEm
}

function removerTarefa(id) {
  // Implemente: use filter() e registre no histórico
}

// --- FILTROS ---

function filtrar({ tag, prioridade, concluida, busca } = {}) {
  // Implemente filtros combinados
  // tag: some() para verificar se a tarefa contém a tag
  // busca: includes() no título e descrição (case-insensitive)
}

// --- ORDENAÇÃO ---

function ordenarTarefas(campo = 'prioridade') {
  // Implemente: sort multi-critério sem mutar o original
}

// --- ESTATÍSTICAS ---

function estatisticas() {
  // Implemente com reduce():
  // - total por prioridade
  // - tempo médio de conclusão (em ms ou horas)
  // - tags mais usadas (flatMap + reduce)
}

// --- DESFAZER ---

function desfazer() {
  // Implemente: restaure o estado anterior usando o histórico
}

// --- TESTES ---
// Crie pelo menos 6 tarefas e exercite todas as funções
criarTarefa('Estudar JavaScript', 'Revisar métodos de array', 1, ['estudo', 'JS']);
criarTarefa('Fazer exercícios', 'Completar lista de exercícios', 2, ['estudo']);
criarTarefa('Comprar mantimentos', 'Mercado e padaria', 3, ['pessoal']);
// Continue...

console.log('Tarefas:', tarefas);
console.log('Estatísticas:', estatisticas());

// %% [markdown]
// ## Exercício — Sistema de Notas com Geração de Boletim
//
// **Métodos:** `map()`, `filter()`, `reduce()`, `sort()`, `flat()`, `every()`, `some()`, `Array.from()`
//
// Gerencie alunos e disciplinas em estrutura 2D e gere relatórios estatísticos completos.
//
// **Estrutura de dados:**
// ```javascript
// alunos = [{ id, nome, notas: { Matemática: [], Português: [], Programação: [] } }]
// ```
//
// **O que implementar:**
// 1. Função `adicionarNota(alunoId, disciplina, nota)` — valida intervalo 0-10 e adiciona
// 2. Função `mediaDisciplina(aluno, disciplina)` — média das notas com `reduce()`
// 3. Função `boletim(aluno)` — `map()` sobre disciplinas → `{ disciplina, media, situação }`
// 4. Média geral do aluno: `reduce()` sobre todas as médias
// 5. Ranking da turma: `sort()` por média geral decrescente com desempate pelo nome
// 6. Relatório da turma: média por disciplina, maior e menor nota (usando `flat()`), % de aprovação
// 7. Use `Array.from({ length: N }, () => Math.round(Math.random() * 10))` para gerar notas simuladas
//
// > 💡 **Dica:** `Object.entries(aluno.notas)` transforma o objeto de notas em array iterável com `map`/`reduce`.

// %%
// Exercício — Sistema de Notas com Boletim

let turma = [
  { id: 1, nome: 'Ana',     notas: { Matemática: [], Português: [], Programação: [] } },
  { id: 2, nome: 'Bruno',   notas: { Matemática: [], Português: [], Programação: [] } },
  { id: 3, nome: 'Carla',   notas: { Matemática: [], Português: [], Programação: [] } },
  { id: 4, nome: 'Diego',   notas: { Matemática: [], Português: [], Programação: [] } },
  { id: 5, nome: 'Elisa',   notas: { Matemática: [], Português: [], Programação: [] } },
];

// 7. Preencha com notas simuladas usando Array.from()
turma.forEach(aluno => {
  Object.keys(aluno.notas).forEach(disc => {
    aluno.notas[disc] = Array.from({ length: 4 }, () => parseFloat((Math.random() * 10).toFixed(1)));
  });
});

// 2. Média de uma disciplina
function mediaDisciplina(aluno, disciplina) {
  // Implemente com reduce()
}

// 3. Boletim individual
function boletim(aluno) {
  // Retorne array: [{ disciplina, media, situacao }]
  // situacao: 'Aprovado' se media >= 5, 'Reprovado' caso contrário
}

// 4. Média geral
function mediaGeral(aluno) {
  // Implemente com reduce() sobre as médias do boletim
}

// 5. Ranking da turma
function ranking() {
  // sort() decrescente por média geral, desempate por nome
}

// 6. Relatório da turma
function relatorioTurma() {
  // Por disciplina: média geral, maior nota, menor nota (use flat())
  // % de aprovação na turma
}

// Exibindo resultados
console.log('=== Boletim — Ana ===');
console.log(boletim(turma[0]));

console.log('\n=== Ranking da Turma ===');
console.log(ranking());

console.log('\n=== Relatório da Turma ===');
console.log(relatorioTurma());

// %% [markdown]
// ## Exercício — Pipeline de Processamento de Dados (ETL)
//
// **Métodos:** `map()`, `filter()`, `reduce()`, `flatMap()`, `sort()`, `Array.from()`, `Set`, `split()`
//
// Processe um dataset tabular completo, aplique transformações em pipeline e gere relatório analítico — como em um processo ETL (Extract, Transform, Load) real.
//
// **O que implementar:**
// 1. **Extração (parse):** `split('\n')` → `map(linha => linha.split(','))` → transforme em objetos com desestruturação
// 2. **Limpeza:** `filter()` para remover linhas inválidas/vazias, `map()` para converter tipos (`parseInt`, `parseFloat`)
// 3. **Agregação por região** com `reduce()`: `{ totalVendas, qtdTransacoes, ticketMedio }`
// 4. **Série temporal:** agrupe vendas por mês com `reduce()`, calcule crescimento percentual mês a mês
// 5. **Top produtos por região:** para cada região, `sort()` + `slice(3)` dos mais vendidos
// 6. **Catálogo único:** `Set` com todos os produtos únicos, ordenado alfabeticamente
// 7. **Relatório final:** array de objetos com todas as métricas consolidadas
//
// > 💡 **Dica:** Processe em etapas encadeadas guardando cada resultado intermediário — facilita debug e legibilidade.

// %%
// Exercício — Pipeline de Processamento de Dados (ETL)

// Dataset CSV (data,região,produto,quantidade,valorUnitario)
const csvBruto = `data,regiao,produto,quantidade,valorUnitario
2025-01-05,Sudeste,Notebook,2,3500
2025-01-12,Norte,Mouse,5,80
2025-01-18,Sudeste,Monitor,1,950
2025-02-02,Sul,Notebook,1,3500
2025-02-09,Sudeste,Teclado,3,150
2025-02-14,Norte,Monitor,2,950
2025-02-28,Sul,Headset,4,200
2025-03-05,Sudeste,Notebook,3,3500
2025-03-10,Norte,Teclado,6,150
2025-03-15,Sul,Mouse,8,80
2025-03-22,Sudeste,Monitor,2,950
2025-03-30,Norte,Headset,3,200
,invalido,,abc,
2025-04-01,Sul,Notebook,1,3500
2025-04-08,Sudeste,Webcam,5,180
2025-04-15,Norte,Notebook,2,3500
2025-04-22,Sul,Monitor,1,950
2025-04-28,Sudeste,Headset,2,200`;

// 1. EXTRAÇÃO — parse do CSV
const linhas = csvBruto.split('\n');
const cabecalho = linhas[0].split(',');

// Transforme as linhas em objetos (use desestruturação)
const registrosBrutos = linhas.slice(1).map(linha => {
  const [data, regiao, produto, quantidade, valorUnitario] = linha.split(',');
  return { data, regiao, produto, quantidade, valorUnitario };
});

// 2. LIMPEZA — remova inválidos e converta tipos
const registros = registrosBrutos
  .filter(r => r.data && r.regiao && r.produto && !isNaN(r.quantidade) && !isNaN(r.valorUnitario))
  .map(r => ({
    data: r.data,
    mes: r.data.substring(0, 7), // 'aaaa-mm'
    regiao: r.regiao,
    produto: r.produto,
    quantidade: parseInt(r.quantidade),
    valorUnitario: parseFloat(r.valorUnitario),
    totalVenda: parseInt(r.quantidade) * parseFloat(r.valorUnitario),
  }));

console.log(`Registros após limpeza: ${registros.length}`);

// 3. AGREGAÇÃO POR REGIÃO
// Implemente com reduce() → { regiao: { totalVendas, qtdTransacoes, ticketMedio } }


// 4. SÉRIE TEMPORAL — vendas por mês e crescimento %
// Implemente com reduce() agrupando por mes


// 5. TOP 3 PRODUTOS POR REGIÃO
// Para cada região: agrupe, some quantidades, sort e slice(3)


// 6. CATÁLOGO ÚNICO
// Use Set para extrair produtos únicos, depois sort()


// 7. RELATÓRIO FINAL
// Consolide todas as métricas em um objeto ou array de objetos
console.log('\n=== RELATÓRIO FINAL ===');
